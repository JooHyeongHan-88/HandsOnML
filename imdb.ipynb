# %%
import pickle

# %%
with open('imdb/train_data.pkl','rb') as f:
    train_data = pickle.load(f)

with open('imdb/train_labels.pkl','rb') as f:
    train_labels = pickle.load(f)

with open('imdb/test_data.pkl','rb') as f:
    test_data = pickle.load(f)

with open('imdb/test_labels.pkl','rb') as f:
    test_labels = pickle.load(f)

with open('imdb/word_index.pkl','rb') as f:
    word_index = pickle.load(f)
